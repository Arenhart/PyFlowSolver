# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# 'D:\\repositories\\PyFlowSolver'

# %%
# %run .\src\volumeManager.py
# %run .\src\sparseArray.py
# %run .\src\velocityArray.py

# %%
vol = np.ones((3,3,3), dtype=np.float32)
vol[1,0,1] = 0
vol[1,2,1] = 0
volume_manager = VolumeManager(vol)
